# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (15,8)

# %% [markdown]
# ### 1. Przygotowanie danych

# %%
df_raw = pd.read_csv('./Diabetes.csv')
df= df_raw.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
columns = [col for col in df_raw.columns if col not in ['Pregnancies', 'Outcome']]
columns
# Out:
# ['Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
df_work = df[columns]

# %%
df_work = df_work.replace(0, np.NaN)

# %%
df[columns] = df_work

# %%
df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   763 non-null    float64
#  2   BloodPressure             733 non-null    float64
#  3   SkinThickness             541 non-null    float64
#  4   Insulin                   394 non-null    float64
#  5   BMI                       757 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB

# %% [markdown]
# ### 2. Corr visualization

# %%
corr = df.corr()
corr
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128135       0.214178       0.100239
# Glucose                      0.128135  1.000000       0.223192       0.228043
# BloodPressure                0.214178  0.223192       1.000000       0.226839
# SkinThickness                0.100239  0.228043       0.226839       1.000000
# Insulin                      0.082171  0.581186       0.098272       0.184888
# BMI                          0.021719  0.232771       0.289230       0.648214
# DiabetesPedigreeFunction    -0.033523  0.137246      -0.002805       0.115016
# Age                          0.544341  0.267136       0.330107       0.166816
# Outcome                      0.221898  0.494650       0.170589       0.259491
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies               0.082171  0.021719                 -0.033523
# ...

# %%
sns.heatmap(corr);

# %%
sns.heatmap(corr, annot=True, cmap='viridis', fmt='0.2f');

# %% [markdown]
# ### - sns corr

# %%
sns.set(style="white")
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(8, 6))
cmap = sns.diverging_palette(200, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, annot=True, cmap=cmap, vmax=0.5, center=0, fmt='0.2f',
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %% [markdown]
# ### - changed figsize, x,y label rotatio, ax font size

# %%
sns.set(style="white", )
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(20,12))
cmap = sns.diverging_palette(200, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, annot=True, cmap=cmap, vmax=1, center=0, fmt='0.2f',
            square=True, linewidths=.5, cbar_kws={"shrink": .5})


# new features
plt.yticks(rotation=10)
plt.xticks(rotation=70)
ax.tick_params(axis='both', which='major', labelsize=12);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8896/4104370694.py in <module>
#       1 sns.set(style="white", )
# ----> 2 mask = np.zeros_like(corr, dtype=bool)
#       3 mask[np.triu_indices_from(mask)] = True
#       4 f, ax = plt.subplots(figsize=(20,12))
#       5 cmap = sns.diverging_palette(200, 10, as_cmap=True)
#
# NameError: name 'corr' is not defined
